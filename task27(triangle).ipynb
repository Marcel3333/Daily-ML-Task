# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import itertools
from sklearn.metrics import adjusted_rand_score
from sklearn.mixture import GaussianMixture

# %%
data = pd.read_csv('../Desktop/ćwiczenia na KMeans/triangle.csv')
scaler = StandardScaler()
df_scaled = scaler.fit_transform(data.drop(columns = ['color']))
plt.scatter(data['x'], data['y'], c = data['color'])
plt.show()

# %%
kmeans = KMeans(n_clusters = 3)
kmeans.fit(df_scaled)
plt.scatter(data['x'], data['y'], c = kmeans.labels_)
plt.show()
#kmeans nieodpowiedni
# Out:
# C:\Users\Marcel\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Marcel\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
gmm = GaussianMixture(n_components = 3, covariance_type = "full")
labels = gmm.fit_predict(df_scaled)
plt.scatter(data['x'], data['y'], c = labels)
plt.show()
# Out:
# C:\Users\Marcel\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
dbscan = DBSCAN(eps = 0.25, min_samples = 8)
dbscan.fit(df_scaled)
plt.scatter(data['x'], data['y'], c = dbscan.labels_)
plt.show()

# %%
ari = adjusted_rand_score(data['color'], dbscan.labels_)
print(f"Adjusted Rand Index: {ari}")
# Out:
# Adjusted Rand Index: 0.9618791856637429
