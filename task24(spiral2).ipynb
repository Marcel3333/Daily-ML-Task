# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import itertools
from sklearn.metrics import adjusted_rand_score
from sklearn.mixture import GaussianMixture

# %%
data = pd.read_csv('../Desktop/ćwiczenia na KMeans/spiral2.csv')
scaler = StandardScaler()
df_scaled = scaler.fit_transform(data.drop(columns = ['color']))
plt.scatter(data['x'], data['y'], c = data['color'])
plt.show()

# %%
dbscan = DBSCAN(eps = 0.09, min_samples = 2)
dbscan.fit(df_scaled)
plt.scatter(data['x'], data['y'], c = dbscan.labels_)
plt.show()

# %%
ari = adjusted_rand_score(data['color'], dbscan.labels_)
print(f"Adjusted Rand Index: {ari}")
# Out:
# Adjusted Rand Index: 0.9920642130207493
